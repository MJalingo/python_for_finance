# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'><img src='../Pierian_Data_Logo.png'/></a>
# ___
# <center><em>Copyright by Pierian Data Inc.</em></center>
# <center><em>For more information, visit us at <a href='http://www.pieriandata.com'>www.pieriandata.com</a></em></center>

# %% [markdown]
# # Pandas and Finance Exercise
# Let's test your new skills!
#
# ## Complete the Tasks in Bold Below.

# %% [markdown]
# **NOTE: For this exercise, you will need to answer the questions below given the dataset of the SP500 (https://finance.yahoo.com/quote/SPY/). Part of the tasks is to download this dataset, if for some reason you can not download this dataset, we have provided a .csv file in this same folder you can read called SPY2000_2021.csv**

# %% [markdown]
# **Task: Import any necessary libraries you think you will need (or just import them as you go along)**

# %%
import pandas as pd
import pandas_datareader.data as web
import matplotlib.pyplot as plt
import yfinance as yf

# %% [markdown]
# **Task: SPY is one of the original index ETFs tracking the S&P 500 group of stocks. Use Python to grab the SPY historical data from Janurary 1st in 2000 to Janurary 1st in 2021.**
#
# *Note: Use any library or method you prefer.*

# %%
data = yf.download("SPY",start="2000-01-01",end="2021-01-01")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2000-01-03  148.250000  148.250000  143.875000  145.437500   94.595078
# 2000-01-04  143.531250  144.062500  139.640625  139.750000   90.895821
# 2000-01-05  139.937500  141.531250  137.250000  140.000000   91.058426
# 2000-01-06  139.625000  141.500000  137.750000  137.750000   89.595001
# 2000-01-07  140.312500  145.750000  140.062500  145.750000   94.798302
# ...                ...         ...         ...         ...         ...
# 2020-12-24  368.079987  369.029999  367.450012  369.000000  355.649200
# 2020-12-28  371.739990  372.589996  371.070007  372.170013  358.704498
# 2020-12-29  373.809998  374.000000  370.829987  371.459991  358.020233
# 2020-12-30  372.339996  373.100006  371.570007  371.989990  358.531006
# 2020-12-31  371.779999  374.660004  371.230011  373.880005  360.352631
#
#               Volume
# Date
# 2000-01-03   8164300
# 2000-01-04   8089800
# 2000-01-05  12177900
# 2000-01-06   6227200
# 2000-01-07   8066500
# ...              ...
# 2020-12-24  26457900
# 2020-12-28  39000400
# 2020-12-29  53680500
# 2020-12-30  49455300
# 2020-12-31  78520700
#
# [5284 rows x 6 columns]

# %%
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2000-01-03  148.250000  148.250000  143.875000  145.437500   97.506668
# 2000-01-04  143.531250  144.062500  139.640625  139.750000   93.693573
# 2000-01-05  139.937500  141.531250  137.250000  140.000000   93.861176
# 2000-01-06  139.625000  141.500000  137.750000  137.750000   92.352676
# 2000-01-07  140.312500  145.750000  140.062500  145.750000   97.716209
# ...                ...         ...         ...         ...         ...
# 2020-12-24  368.079987  369.029999  367.450012  369.000000  366.596039
# 2020-12-28  371.739990  372.589996  371.070007  372.170013  369.745392
# 2020-12-29  373.809998  374.000000  370.829987  371.459991  369.040009
# 2020-12-30  372.339996  373.100006  371.570007  371.989990  369.566559
# 2020-12-31  371.779999  374.660004  371.230011  373.880005  371.444244
#
#               Volume
# Date
# 2000-01-03   8164300
# 2000-01-04   8089800
# 2000-01-05  12177900
# 2000-01-06   6227200
# 2000-01-07   8066500
# ...              ...
# 2020-12-24  26457900
# 2020-12-28  39000400
# 2020-12-29  53680500
# 2020-12-30  49455300
# 2020-12-31  78520700
#
# [5284 rows x 6 columns]

# %%
# Alternatively you can use read_csv to read the provided csv file. Just make sure to set index_col="Date"
csv_data = pd.read_csv("SPY2000_2021.csv",index_col="Date",parse_dates=True)

# %% [markdown]
# **Task: Check the head of the ten first entries in the dataset**

# %%
data.head(10)
# Out:
#                  Open       High         Low      Close  Adj Close    Volume
# Date
# 2000-01-03  148.25000  148.25000  143.875000  145.43750  94.595078   8164300
# 2000-01-04  143.53125  144.06250  139.640625  139.75000  90.895821   8089800
# 2000-01-05  139.93750  141.53125  137.250000  140.00000  91.058426  12177900
# 2000-01-06  139.62500  141.50000  137.750000  137.75000  89.595001   6227200
# 2000-01-07  140.31250  145.75000  140.062500  145.75000  94.798302   8066500
# 2000-01-10  146.25000  146.90625  145.031250  146.25000  95.123505   5741700
# 2000-01-11  145.81250  146.09375  143.500000  144.50000  93.985306   7503700
# 2000-01-12  144.59375  144.59375  142.875000  143.06250  93.050308   6907700
# 2000-01-13  144.46875  145.75000  143.281250  145.00000  94.310509   5158300
# 2000-01-14  146.53125  147.46875  145.968750  146.96875  95.590996   7437300

# %%
# Out:
#                  Open       High         Low      Close  Adj Close    Volume
# Date
# 2000-01-03  148.25000  148.25000  143.875000  145.43750  97.506668   8164300
# 2000-01-04  143.53125  144.06250  139.640625  139.75000  93.693573   8089800
# 2000-01-05  139.93750  141.53125  137.250000  140.00000  93.861176  12177900
# 2000-01-06  139.62500  141.50000  137.750000  137.75000  92.352676   6227200
# 2000-01-07  140.31250  145.75000  140.062500  145.75000  97.716209   8066500
# 2000-01-10  146.25000  146.90625  145.031250  146.25000  98.051422   5741700
# 2000-01-11  145.81250  146.09375  143.500000  144.50000  96.878143   7503700
# 2000-01-12  144.59375  144.59375  142.875000  143.06250  95.914406   6907700
# 2000-01-13  144.46875  145.75000  143.281250  145.00000  97.213379   5158300
# 2000-01-14  146.53125  147.46875  145.968750  146.96875  98.533318   7437300

# %% [markdown]
# **Task: Check the datatype of all entries**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5284 entries, 2000-01-03 to 2020-12-31
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       5284 non-null   float64
#  1   High       5284 non-null   float64
#  2   Low        5284 non-null   float64
#  3   Close      5284 non-null   float64
#  4   Adj Close  5284 non-null   float64
#  5   Volume     5284 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 289.0 KB

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5284 entries, 2000-01-03 to 2020-12-31
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       5284 non-null   float64
#  1   High       5284 non-null   float64
#  2   Low        5284 non-null   float64
#  3   Close      5284 non-null   float64
#  4   Adj Close  5284 non-null   float64
#  5   Volume     5284 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 289.0 KB

# %% [markdown]
# **Task: Plot the Adjusted Closing price of the SP500, with the price on the y axis and the year on the x axis. Use Locator() and Formatter() techniques to configure the plot x axis so that you can see a tick for every year in the dataset (only showing the year number, not the full YYYY-MM-DD that is the default). Choose a reasonable figure size, set the dpi to 300 and save this plot in your working directory as sp500.png**

# %%
from matplotlib import dates
fig = plt.figure(dpi=300,figsize=(10,5))
fig.add_axes([0,0,1,1])
ax = data["Adj Close"].plot()

ax.xaxis.set_major_locator(dates.YearLocator())
ax.xaxis.set_major_formatter(dates.DateFormatter("%Y"))

ax.tick_params("x",which="major",rotation=60)

plt.savefig("Sp500.png")

# %% [markdown]
# **Task: Create a histogram of the daily volume of shares of SPY traded. Choose a reasonable bin size.**

# %%
fig, ax = plt.subplots(dpi=68)
ax.hist(data["Volume"], bins=50)
ax.xaxis.grid(True,which="major")
ax.yaxis.grid(True,which="major")

# %%
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Task: Let's explore the crash and recovery of 2020 due to the COVID pandemic. Create a line plot of the Adj. Close price from 1-1-2020 to 1-1-2021. The xaxis ticks should be formatted by YYYY-MM**

# %%
start,end = pd.Timestamp("2020-01-01"),pd.Timestamp("2021-01-01")

# %%
plt.figure(dpi=200,figsize=(13,10))
ax = data["Adj Close"].plot(xlim=[start,end])
ax.xaxis.set_major_locator(dates.MonthLocator())
ax.xaxis.set_major_formatter(dates.DateFormatter("%Y-%m"))

# %% [markdown]
# **Task: Create a plot whichs shows the adjusted closing price of SPY for the entire length of the time series along with an added trend line of the corresponding 200 days rolling mean of the adj. close price. Make sure to add a legend that identifies each line.**

# %%
plt.figure(dpi=80,figsize=(12.5,10))
data["Adj Close"].plot(label="Adj Close")
data["Adj Close"].rolling(window=200).mean().plot(label="252 MA of Adj Close")
plt.legend()

# %% [markdown]
# **Task: If you bought one share at the start of the time series on Jan 1st 2000, how much money would you have gained (in Adj. Close Dollar amount) by Jan 1st 2021?**
#
# Take the adjusted closing price as reference

# %%
data["Adj Close"].diff().cumsum().max()
# Out:
# 265.75755310058594

# %%
# Out:
# 273.9375762939453

# %% [markdown]
# **Task: What was the percent increase in value (based on Adj. Close price) from Jan 1st, 2000 to Jan 1st 2021?**

# %%
# CODE HERE

# %%
# Out:
# 280.9424028711478

# %% [markdown]
# **Task: Return the 10 dates with the largest gain for the SPY.**

# %%
data["Adj Close"].sort_values(ascending=False).head(10)
# Out:
# Date
# 2020-12-31    360.352631
# 2020-12-28    358.704498
# 2020-12-30    358.531006
# 2020-12-29    358.020233
# 2020-12-17    357.249176
# 2020-12-18    355.822632
# 2020-12-24    355.649200
# 2020-12-08    355.262482
# 2020-12-16    355.262482
# 2020-12-04    354.955383
# Name: Adj Close, dtype: float64

# %%
# Out:
# Date
# 2008-10-13    0.145198
# 2008-10-28    0.116855
# 2020-03-24    0.090603
# 2020-03-13    0.085486
# 2009-03-23    0.071829
# 2008-11-24    0.069291
# 2020-04-06    0.067166
# 2008-11-13    0.062340
# 2008-10-20    0.060079
# 2002-07-24    0.059662
# Name: Adj Close, dtype: float64

# %% [markdown]
# **TASK: What were the 10 dates with the highest daily percent change from the previous day (either gain OR decrease).**

# %%
#CODE HERE

# %%
# Out:
# Date
# 2008-10-13    0.145198
# 2008-10-28    0.116855
# 2020-03-16    0.109424
# 2008-10-15    0.098448
# 2020-03-12    0.095677
# 2020-03-24    0.090603
# 2008-12-01    0.088578
# 2020-03-13    0.085486
# 2008-09-29    0.078362
# 2020-03-09    0.078094
# Name: Adj Close, dtype: float64

# %% [markdown]
# **Task: For each year in the dataset, find the Maximum Adj. Close price that SPY reached for that year.**

# %%
# CODE HERE

# %%
# Out:
# Date
# 2000-12-31    103.215630
# 2001-12-31     93.445862
# 2002-12-31     80.819427
# 2003-12-31     78.830391
# 2004-12-31     87.617325
# 2005-12-31     93.406265
# 2006-12-31    106.637589
# 2007-12-31    118.622261
# 2008-12-31    110.449692
# 2009-12-31     90.006927
# 2010-12-31    102.520927
# 2011-12-31    111.560455
# 2012-12-31    123.567558
# 2013-12-31    160.097992
# 2014-12-31    184.463684
# 2015-12-31    189.640625
# 2016-12-31    208.626770
# 2017-12-31    251.921860
# 2018-12-31    278.109100
# 2019-12-31    314.954376
# 2020-12-31    371.444244
# Freq: A-DEC, Name: Adj Close, dtype: float64

# %% [markdown]
# **Task: What was the day with the lowest adjusted closing price in 2020? (and what was this price)**
#
# Hint: Check out idxmin()

# %%
# CODE HERE

# %%
# Out:
# Timestamp('2020-03-23 00:00:00')

# %%
# Out:
# 218.7155303955078

# %% [markdown]
# **Task: In 2020, due to the uncertainty of the COVID-19 pandemic, the S&P500 index experienced a large drop in March of 2020. What was the highest price reached in 2020 *before* April 1st, 2020.**

# %%
# CODE HERE

# %%
# Out:
# Timestamp('2020-02-19 00:00:00')

# %%
# Out:
# 329.97357177734375

# %% [markdown]
# **Task: Due to central bank and government actions, the S&P500 had one of the quickest recoveries in history after the crash of March 2020. How long did it take (in days) to reach the peak price the S&P 500 was at before the crash in March? In other words, based on your previous task of finding the peak price before the crash, how long did it take for the market to recover to its pre-crash price level?**
#
# Hint: You can subtract datetime timestamps from each other

# %%
# Out:
# Date
# 2020-08-10    330.645203
# 2020-08-12    332.487732
# 2020-08-13    331.886688
# 2020-08-14    331.896545
# 2020-08-17    332.950867
#                  ...
# 2020-12-24    366.596039
# 2020-12-28    369.745392
# 2020-12-29    369.040009
# 2020-12-30    369.566559
# 2020-12-31    371.444244
# Name: Adj Close, Length: 86, dtype: float64

# %%
# Out:
# 330.64520263671875

# %%
# Out:
# Timestamp('2020-02-19 00:00:00')

# %%
# Out:
# Timedelta('173 days 00:00:00')
