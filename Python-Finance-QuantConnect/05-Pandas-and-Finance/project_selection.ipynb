# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("C:\\Users\\ncair\\Downloads\\Class Quiz Week3_1 (Responses) - Form Responses 1.csv")
proj = pd.read_csv("C:\\Users\\ncair\\Downloads\\Project (beginner) cohort 9 - Group.csv")

# %%
data = data.set_index("Name")

# %%
data['Name']
# Out:
# 0                   Omotola David
# 1                    Gloria Davut
# 2           Chinyere angel ozioko
# 3             EKEH ARINZE SUCCESS
# 4      Dangana Hawakulu Abdullahi
# 5                 victor okey udo
# 6           Aisha Muhammed Gidado
# 7           DIKE ZITA CHINECHEREM
# 8                 adewumi ayomide
# 9             Mubarak Mohammed O.
# 10          Arinze-Uhuo Chimsimdi
# 11            Odey Augustine Adie
# 12                   Fatima Barwa
# 13                    Chiedu Elue
# 14            Amina Muhammad Abdu
# 15        Hussaina Muhammad Shehu
# 16                Olamide Kolade
# 17             Chukwudi Iwuchukwu
# 18         mazino dickson-amagada
# 19          Oloye Kudirat Adenike
# 20          olusegun oluwaseyitan
# 21    Mohammed Abdulrasheed Taiye
# 22         Zane Richards-Offohndu
# 23         Khalid Abdulhamid Zago
# 24              Jasmine Hamilton
# 25                  Hassana Onipe
# 26            Chiedu Clement Elue
# Name: Name, dtype: object

# %%
for i in range(len(data["Score"])):
    data["Score"][i] = int(data["Score"][i].split()[0])
# Out:
# C:\Users\ncair\AppData\Local\Temp\ipykernel_7712\2569292797.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Score"][i] = int(data["Score"][i].split()[0])

# %%
data["Timestamp"] = pd.to_datetime(data["Timestamp"])

# %%
data
# Out:
#              Timestamp Score                         Name  \
# 0  2023-07-20 08:46:35    30                Omotola David
# 1  2023-07-20 08:47:11    30                 Gloria Davut
# 2  2023-07-20 08:48:09    18        Chinyere angel ozioko
# 3  2023-07-20 08:48:12    22          EKEH ARINZE SUCCESS
# 4  2023-07-20 08:48:41    30   Dangana Hawakulu Abdullahi
# 5  2023-07-20 08:48:59    20              victor okey udo
# 6  2023-07-20 08:50:16    18        Aisha Muhammed Gidado
# 7  2023-07-20 08:52:11    20        DIKE ZITA CHINECHEREM
# 8  2023-07-20 08:52:34    26              adewumi ayomide
# 9  2023-07-20 08:53:33    14          Mubarak Mohammed O.
# 10 2023-07-20 08:54:00    20        Arinze-Uhuo Chimsimdi
# 11 2023-07-20 08:54:40    12          Odey Augustine Adie
# 12 2023-07-20 08:54:48    18                 Fatima Barwa
# 13 2023-07-20 08:55:13    18                  Chiedu Elue
# 14 2023-07-20 08:55:44    30          Amina Muhammad Abdu
# ...
